# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !tsp_main # best 9074.147
# Out:
# 0) max = 30975.596, mean = 26376.289, min = 21336.543
# 1000) max = 12227.034, mean = 9215.960, min = 9074.146
#
# Best solution saved to best_solution.csv
#
#
#
# 				Best Order Solution
# |4 |28 |2 |25 |8 |11 |5 |27 |0 |23 |12 |15 |26 |7 |22 |6 |24 |18 |10 |21 |16 |13 |17 |14 |3 |9 |19 |1 |20 |

# %%
# Load CSV
df = pd.read_csv("best_solution.csv")
new_row = {'Location_ID':df['Location_ID'][0], 'X': df['X'][0], 'Y': df['Y'][0]}
df.loc[len(df)] = new_row

# Plot the path
plt.plot(df["X"], df["Y"], marker='o', linestyle='-')
plt.scatter(df["X"], df["Y"], color='red')  # Highlight points
plt.xlabel("X Coordinate")
plt.ylabel("Y Coordinate")
plt.title("Best Found TSP Solution Path")
plt.show()

# %%
l=  [24, 19, 23, 12, 0, 3, 29, 7, 8, 0, 
                   2, 22, 25, 15, 5, 16, 26, 21, 10, 17, 
                   28, 14, 13, 1, 9, 4, 18, 11, 20, 27]

# %%
len(l)
# Out:
# 30
